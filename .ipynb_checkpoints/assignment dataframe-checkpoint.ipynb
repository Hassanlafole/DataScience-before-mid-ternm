# %%
import pandas as pd

# %%
##Exercise for Dictionary as DataFrame

data={'region':['banaadir','baydhabo','bakool','bakool'],'area':[3535,5775,9838,466363],'population':[3737,8448,3939,38373]}

# %%
regions=pd.DataFrame(data)

# %%
regions
# Out:
#      region    area  population
# 0  banaadir    3535        3737
# 1  baydhabo    5775        8448
# 2    bakool    9838        3939
# 3    bakool  466363       38373

# %%
df=pd.read_csv("D:\datasetpandas/movies.csv")

# %%
df.head()
# Out:
#                                          title   industry  release_year  \
# 0                              Pather Panchali  Bollywood          1955
# 1  Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                        Thor: The Dark World   Hollywood          2013
# 3                              Thor: Ragnarok   Hollywood          2017
# 4                      Thor: Love and Thunder   Hollywood          2022
#
#    imdb_rating                     studio   budget   revenue       unit  \
# 0          8.3  Government of West Bengal  70000.0  100000.0  Thousands
# 1          7.0             Marvel Studios    200.0     954.8   Millions
# 2          6.8             Marvel Studios    165.0     644.8   Millions
# 3          7.9             Marvel Studios    180.0     854.0   Millions
# 4          6.8             Marvel Studios    250.0     670.0   Millions
#
#   currency language
# 0      INR  Bengali
# 1      USD  English
# 2      USD  English
# ...

# %%
df.shape
# Out:
# (37, 10)

# %%
df.columns
# Out:
# Index(['title', 'industry', 'release_year', 'imdb_rating', 'studio', 'budget',
#        'revenue', 'unit', 'currency', 'language'],
#       dtype='object')

# %%
df["language"]
# Out:
# 0     Bengali
# 1     English
# 2     English
# 3     English
# 4     English
# 5     English
# 6     English
# 7     English
# 8     English
# 9     English
# 10    English
# 11    English
# 12    English
# 13    English
# 14    English
# 15    English
# 16    English
# 17    English
# 18    English
# 19    English
# 20    English
# 21      Hindi
# 22      Hindi
# 23      Hindi
# 24      Hindi
# 25      Hindi
# 26      Hindi
# 27      Hindi
# 28      Hindi
# 29      Hindi
# 30      Hindi
# 31      Hindi
# 32      Hindi
# 33    Kannada
# 34     Telugu
# 35     Telugu
# 36     Telugu
# Name: language, dtype: object

# %%
df.language.value_counts()
# Out:
# language
# English    20
# Hindi      12
# Telugu      3
# Bengali     1
# Kannada     1
# Name: count, dtype: int64

# %%
df[["industry","language","revenue"]].head()
# Out:
#     industry language   revenue
# 0  Bollywood  Bengali  100000.0
# 1  Hollywood  English     954.8
# 2  Hollywood  English     644.8
# 3  Hollywood  English     854.0
# 4  Hollywood  English     670.0

# %%
df[(df.imdb_rating>=8.0)].head()
# Out:
#                       title   industry  release_year  imdb_rating  \
# 0           Pather Panchali  Bollywood          1955          8.3
# 5  The Shawshank Redemption  Hollywood          1994          9.3
# 6              Interstellar  Hollywood          2014          8.6
# 7  The Pursuit of Happyness  Hollywood          2006          8.0
# 8                 Gladiator  Hollywood          2000          8.5
#
#                       studio   budget   revenue       unit currency language
# 0  Government of West Bengal  70000.0  100000.0  Thousands      INR  Bengali
# 5  Castle Rock Entertainment     25.0      73.3   Millions      USD  English
# 6      Warner Bros. Pictures    165.0     701.8   Millions      USD  English
# 7          Columbia Pictures     55.0     307.1   Millions      USD  English
# 8       Universal Pictures      103.0     460.5   Millions      USD  English

# %%
df[(df.language=="English") & (df.industry!="Bollywood")]
# Out:
#                                           title   industry  release_year  \
# 1   Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                         Thor: The Dark World   Hollywood          2013
# 3                               Thor: Ragnarok   Hollywood          2017
# 4                       Thor: Love and Thunder   Hollywood          2022
# 5                      The Shawshank Redemption  Hollywood          1994
# 6                                  Interstellar  Hollywood          2014
# 7                      The Pursuit of Happyness  Hollywood          2006
# 8                                     Gladiator  Hollywood          2000
# 9                                       Titanic  Hollywood          1997
# 10                        It's a Wonderful Life  Hollywood          1946
# 11                                       Avatar  Hollywood          2009
# 12                                The Godfather  Hollywood          1972
# ...

# %%
df[["budget","revenue"]].describe()
# Out:
#              budget        revenue
# count     37.000000      37.000000
# mean    2084.975135    4117.135135
# std    11477.487145   16372.462682
# min        1.000000       3.100000
# 25%       15.500000     263.100000
# 50%      165.000000     701.800000
# 75%      250.000000    2000.000000
# max    70000.000000  100000.000000

# %%
df["filmAge"]=df.release_year.apply(lambda x:2023-x)

# %%
df[["release_year","filmAge"]]
# Out:
#     release_year  filmAge
# 0           1955       68
# 1           2022        1
# 2           2013       10
# 3           2017        6
# 4           2022        1
# 5           1994       29
# 6           2014        9
# 7           2006       17
# 8           2000       23
# 9           1997       26
# 10          1946       77
# 11          2009       14
# 12          1972       51
# 13          2008       15
# 14          1993       30
# 15          1993       30
# 16          2019        4
# 17          2019        4
# 18          2018        5
# 19          2011       12
# 20          2014        9
# 21          1995       28
# 22          2009       14
# 23          2001       22
# 24          2015        8
# 25          2007       16
# 26          2003       20
# 27          2014        9
# 28          2018        5
# 29          2022        1
# 30          2015        8
# 31          2018        5
# 32          2021        2
# 33          2022        1
# ...

# %%
df.set_index("title",inplace=True)

# %%
df.index
# Out:
# Index(['Pather Panchali', 'Doctor Strange in the Multiverse of Madness',
#        'Thor: The Dark World ', 'Thor: Ragnarok ', 'Thor: Love and Thunder ',
#        'The Shawshank Redemption', 'Interstellar', 'The Pursuit of Happyness',
#        'Gladiator', 'Titanic', 'It's a Wonderful Life', 'Avatar',
#        'The Godfather', 'The Dark Knight', 'Schindler's List', 'Jurassic Park',
#        'Parasite', 'Avengers: Endgame', 'Avengers: Infinity War',
#        'Captain America: The First Avenger',
#        'Captain America: The Winter Soldier', 'Dilwale Dulhania Le Jayenge',
#        '3 Idiots', 'Kabhi Khushi Kabhie Gham', 'Bajirao Mastani ',
#        'Taare Zameen Par', 'Munna Bhai M.B.B.S.', 'PK', 'Sanju',
#        'The Kashmir Files', 'Bajrangi Bhaijaan', 'Race 3', 'Shershaah',
#        'K.G.F: Chapter 2', 'Pushpa: The Rise - Part 1', 'RRR',
#        'Baahubali: The Beginning'],
#       dtype='object', name='title')

# %%
df.loc["PK"]
# Out:
# industry                 Bollywood
# release_year                  2014
# imdb_rating                    8.1
# studio          Vinod Chopra Films
# budget                       850.0
# revenue                     8540.0
# unit                      Millions
# currency                       INR
# language                     Hindi
# filmAge                          9
# Name: PK, dtype: object

# %%
df.iloc[10:13]
# Out:
#                         industry  release_year  imdb_rating  \
# title
# It's a Wonderful Life  Hollywood          1946          8.6
# Avatar                 Hollywood          2009          7.8
# The Godfather          Hollywood          1972          9.2
#
#                                    studio  budget  revenue      unit currency  \
# title
# It's a Wonderful Life       Liberty Films    3.18      3.3  Millions      USD
# Avatar                   20th Century Fox  237.00   2847.0  Millions      USD
# The Godfather          Paramount Pictures    7.20    291.0  Millions      USD
#
#                       language  filmAge
# title
# It's a Wonderful Life  English       77
# Avatar                 English       14
# The Godfather          English       51

# %%
df.imdb_rating.max()
# Out:
# 9.3

# %%
df.imdb_rating.min()
# Out:
# 1.9

# %%
df[(df.imdb_rating==df.imdb_rating.max()) | (df.imdb_rating==df.imdb_rating.min())]
# Out:
#                            industry  release_year  imdb_rating  \
# title
# The Shawshank Redemption  Hollywood          1994          9.3
# Race 3                    Bollywood          2018          1.9
#
#                                              studio  budget  revenue  \
# title
# The Shawshank Redemption  Castle Rock Entertainment    25.0     73.3
# Race 3                            Salman Khan Films     1.8      3.1
#
#                               unit currency language  filmAge
# title
# The Shawshank Redemption  Millions      USD  English       29
# Race 3                    Billions      INR    Hindi        5

# %%
#Exercise for getting profit from movies dataset & getting columns based on conditions
df['Profit'] = df['revenue'] - df['budget']

# %%
df
# Out:
#                                               industry  release_year  \
# title
# Pather Panchali                              Bollywood          1955
# Doctor Strange in the Multiverse of Madness  Hollywood          2022
# Thor: The Dark World                         Hollywood          2013
# Thor: Ragnarok                               Hollywood          2017
# Thor: Love and Thunder                       Hollywood          2022
# The Shawshank Redemption                     Hollywood          1994
# Interstellar                                 Hollywood          2014
# The Pursuit of Happyness                     Hollywood          2006
# Gladiator                                    Hollywood          2000
# Titanic                                      Hollywood          1997
# It's a Wonderful Life                        Hollywood          1946
# Avatar                                       Hollywood          2009
# ...

# %%
df.head()
# Out:
#                                               industry  release_year  \
# title
# Pather Panchali                              Bollywood          1955
# Doctor Strange in the Multiverse of Madness  Hollywood          2022
# Thor: The Dark World                         Hollywood          2013
# Thor: Ragnarok                               Hollywood          2017
# Thor: Love and Thunder                       Hollywood          2022
#
#                                              imdb_rating  \
# title
# Pather Panchali                                      8.3
# Doctor Strange in the Multiverse of Madness          7.0
# Thor: The Dark World                                 6.8
# Thor: Ragnarok                                       7.9
# Thor: Love and Thunder                               6.8
#
#                                                                 studio  \
# title
# Pather Panchali                              Government of West Bengal
# ...

# %%
df[(df.language=="English") & (df.Profit >=400)]
# Out:
#                                               industry  release_year  \
# title
# Doctor Strange in the Multiverse of Madness  Hollywood          2022
# Thor: The Dark World                         Hollywood          2013
# Thor: Ragnarok                               Hollywood          2017
# Thor: Love and Thunder                       Hollywood          2022
# Interstellar                                 Hollywood          2014
# Titanic                                      Hollywood          1997
# Avatar                                       Hollywood          2009
# The Dark Knight                              Hollywood          2008
# Jurassic Park                                Hollywood          1993
# Avengers: Endgame                            Hollywood          2019
# Avengers: Infinity War                       Hollywood          2018
# Captain America: The Winter Soldier          Hollywood          2014
#
#                                              imdb_rating  \
# ...

# %%
df[(df.revenue<=954) & (df.Profit !=2002)]
# Out:
#                                       industry  release_year  imdb_rating  \
# title
# Thor: The Dark World                 Hollywood          2013          6.8
# Thor: Ragnarok                       Hollywood          2017          7.9
# Thor: Love and Thunder               Hollywood          2022          6.8
# The Shawshank Redemption             Hollywood          1994          9.3
# Interstellar                         Hollywood          2014          8.6
# The Pursuit of Happyness             Hollywood          2006          8.0
# Gladiator                            Hollywood          2000          8.5
# It's a Wonderful Life                Hollywood          1946          8.6
# The Godfather                        Hollywood          1972          9.2
# Schindler's List                     Hollywood          1993          9.0
# Parasite                             Hollywood          2019          8.5
# Captain America: The First Avenger   Hollywood          2011          6.9
# ...

# %%
df[(df.currency=="USD")&(df.Profit>=700)]
# Out:
#                                               industry  release_year  \
# title
# Doctor Strange in the Multiverse of Madness  Hollywood          2022
# Titanic                                      Hollywood          1997
# Avatar                                       Hollywood          2009
# The Dark Knight                              Hollywood          2008
# Jurassic Park                                Hollywood          1993
# Avengers: Endgame                            Hollywood          2019
# Avengers: Infinity War                       Hollywood          2018
#
#                                              imdb_rating              studio  \
# title
# Doctor Strange in the Multiverse of Madness          7.0      Marvel Studios
# Titanic                                              7.9  Paramount Pictures
# Avatar                                               7.8    20th Century Fox
# The Dark Knight                                      9.0             Syncopy
# ...
