# %% [markdown]
# ## Dataframe practice

# %%
import pandas as pd

# %%
area = [984,645,5564,643]
population = [1000, 500, 643,6432]
region = ["Gedo", "Bay", "Hiiraan", "Togdheer"]
regions=pd.DataFrame({"Region" : region , "Population" :population, "Area":area})

# %%
regions
# Out:
#      Region  Population  Area
# 0      Gedo        1000   984
# 1       Bay         500   645
# 2   Hiiraan         643  5564
# 3  Togdheer        6432   643

# %% [markdown]
# ## Reading Dataset using movies

# %%
moviesdf =pd.read_csv("movies.csv")

# %%
moviesdf
# Out:
#                                           title   industry  release_year  \
# 0                               Pather Panchali  Bollywood          1955
# 1   Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                         Thor: The Dark World   Hollywood          2013
# 3                               Thor: Ragnarok   Hollywood          2017
# 4                       Thor: Love and Thunder   Hollywood          2022
# 5                      The Shawshank Redemption  Hollywood          1994
# 6                                  Interstellar  Hollywood          2014
# 7                      The Pursuit of Happyness  Hollywood          2006
# 8                                     Gladiator  Hollywood          2000
# 9                                       Titanic  Hollywood          1997
# 10                        It's a Wonderful Life  Hollywood          1946
# 11                                       Avatar  Hollywood          2009
# ...

# %%
moviesdf.columns
# Out:
# Index(['title', 'industry', 'release_year', 'imdb_rating', 'studio', 'budget',
#        'revenue', 'unit', 'currency', 'language'],
#       dtype='object')

# %%
moviesdf.shape
# Out:
# (37, 10)

# %%
moviesdf.industry
# Out:
# 0     Bollywood
# 1     Hollywood
# 2     Hollywood
# 3     Hollywood
# 4     Hollywood
# 5     Hollywood
# 6     Hollywood
# 7     Hollywood
# 8     Hollywood
# 9     Hollywood
# 10    Hollywood
# 11    Hollywood
# 12    Hollywood
# 13    Hollywood
# 14    Hollywood
# 15    Hollywood
# 16    Hollywood
# 17    Hollywood
# 18    Hollywood
# 19    Hollywood
# 20    Hollywood
# 21    Bollywood
# 22    Bollywood
# 23    Bollywood
# 24    Bollywood
# 25    Bollywood
# 26    Bollywood
# 27    Bollywood
# 28    Bollywood
# 29    Bollywood
# 30    Bollywood
# 31    Bollywood
# 32    Bollywood
# 33    Bollywood
# 34    Bollywood
# 35    Bollywood
# 36    Bollywood
# Name: industry, dtype: object

# %%
moviesdf.language
# Out:
# 0     Bengali
# 1     English
# 2     English
# 3     English
# 4     English
# 5     English
# 6     English
# 7     English
# 8     English
# 9     English
# 10    English
# 11    English
# 12    English
# 13    English
# 14    English
# 15    English
# 16    English
# 17    English
# 18    English
# 19    English
# 20    English
# 21      Hindi
# 22      Hindi
# 23      Hindi
# 24      Hindi
# 25      Hindi
# 26      Hindi
# 27      Hindi
# 28      Hindi
# 29      Hindi
# 30      Hindi
# 31      Hindi
# 32      Hindi
# 33    Kannada
# 34     Telugu
# 35     Telugu
# 36     Telugu
# Name: language, dtype: object

# %%
moviesdf.title
# Out:
# 0                                 Pather Panchali
# 1     Doctor Strange in the Multiverse of Madness
# 2                           Thor: The Dark World
# 3                                 Thor: Ragnarok
# 4                         Thor: Love and Thunder
# 5                        The Shawshank Redemption
# 6                                    Interstellar
# 7                        The Pursuit of Happyness
# 8                                       Gladiator
# 9                                         Titanic
# 10                          It's a Wonderful Life
# 11                                         Avatar
# 12                                  The Godfather
# 13                                The Dark Knight
# 14                               Schindler's List
# 15                                  Jurassic Park
# 16                                       Parasite
# 17                              Avengers: Endgame
# 18                         Avengers: Infinity War
# ...

# %%
moviesdf.industry.value_counts()
# Out:
# Hollywood    20
# Bollywood    17
# Name: industry, dtype: int64

# %%
moviesdf.language.value_counts()
# Out:
# English    20
# Hindi      12
# Telugu      3
# Bengali     1
# Kannada     1
# Name: language, dtype: int64

# %%
moviesdf.currency.value_counts()
# Out:
# USD    20
# INR    17
# Name: currency, dtype: int64

# %%
moviesdf[["industry","studio", "budget"]].head() #gettinf special columns
# Out:
#     industry                     studio   budget
# 0  Bollywood  Government of West Bengal  70000.0
# 1  Hollywood             Marvel Studios    200.0
# 2  Hollywood             Marvel Studios    165.0
# 3  Hollywood             Marvel Studios    180.0
# 4  Hollywood             Marvel Studios    250.0

# %%
moviesdf[(moviesdf.industry=='Hollywood') & (moviesdf.budget>200)] #multiple condition
# Out:
#                                  title   industry  release_year  imdb_rating  \
# 4              Thor: Love and Thunder   Hollywood          2022          6.8
# 11                              Avatar  Hollywood          2009          7.8
# 17                   Avengers: Endgame  Hollywood          2019          8.4
# 18              Avengers: Infinity War  Hollywood          2018          8.4
# 19  Captain America: The First Avenger  Hollywood          2011          6.9
#
#               studio  budget  revenue      unit currency language
# 4     Marvel Studios   250.0    670.0  Millions      USD  English
# 11  20th Century Fox   237.0   2847.0  Millions      USD  English
# 17    Marvel Studios   400.0   2798.0  Millions      USD  English
# 18    Marvel Studios   400.0   2048.0  Millions      USD  English
# 19    Marvel Studios   216.7    370.6  Millions      USD  English

# %%
moviesdf[["imdb_rating", "budget", "revenue"]].describe()
# Out:
#        imdb_rating        budget        revenue
# count    36.000000     37.000000      37.000000
# mean      7.919444   2084.975135    4117.135135
# std       1.204947  11477.487145   16372.462682
# min       1.900000      1.000000       3.100000
# 25%       7.800000     15.500000     263.100000
# 50%       8.100000    165.000000     701.800000
# 75%       8.400000    250.000000    2000.000000
# max       9.300000  70000.000000  100000.000000

# %%
moviesdf.imdb_rating.min()
# Out:
# 1.9

# %%
moviesdf.imdb_rating.max()
# Out:
# 9.3

# %%
moviesdf[(moviesdf.imdb_rating==moviesdf.imdb_rating.max())]
# Out:
#                       title   industry  release_year  imdb_rating  \
# 5  The Shawshank Redemption  Hollywood          1994          9.3
#
#                       studio  budget  revenue      unit currency language
# 5  Castle Rock Entertainment    25.0     73.3  Millions      USD  English

# %%
moviesdf["Age"] = moviesdf.release_year.apply(lambda x : 2023-x)

# %%
moviesdf.head()
# Out:
#                                          title   industry  release_year  \
# 0                              Pather Panchali  Bollywood          1955
# 1  Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                        Thor: The Dark World   Hollywood          2013
# 3                              Thor: Ragnarok   Hollywood          2017
# 4                      Thor: Love and Thunder   Hollywood          2022
#
#    imdb_rating                     studio   budget   revenue       unit  \
# 0          8.3  Government of West Bengal  70000.0  100000.0  Thousands
# 1          7.0             Marvel Studios    200.0     954.8   Millions
# 2          6.8             Marvel Studios    165.0     644.8   Millions
# 3          7.9             Marvel Studios    180.0     854.0   Millions
# 4          6.8             Marvel Studios    250.0     670.0   Millions
#
#   currency language  Age
# 0      INR  Bengali   68
# 1      USD  English    1
# ...

# %%
moviesdf["Profit"] = moviesdf.budget.apply(lambda x : revenue-x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 moviesdf["Profit"] = moviesdf.budget.apply(lambda x : revenue-x)
#
# File C:\Anaconda\Lib\site-packages\pandas\core\series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
#    4662     self,
#    4663     func: AggFuncType,
#    (...)
#    4666     **kwargs,
#    4667 ) -> DataFrame | Series:
#    4668     """
#    4669     Invoke function on values of Series.
#    4670
#    (...)
#    4769     dtype: float64
#    4770     """
# -> 4771     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File C:\Anaconda\Lib\site-packages\pandas\core\apply.py:1123, in SeriesApply.apply(self)
#    1120     return self.apply_str()
#    1122 # self.f is Callable
# -> 1123 return self.apply_standard()
#
# ...

# %%
moviesdf.head()
# Out:
#                                          title   industry  release_year  \
# 0                              Pather Panchali  Bollywood          1955
# 1  Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                        Thor: The Dark World   Hollywood          2013
# 3                              Thor: Ragnarok   Hollywood          2017
# 4                      Thor: Love and Thunder   Hollywood          2022
#
#    imdb_rating                     studio   budget   revenue       unit  \
# 0          8.3  Government of West Bengal  70000.0  100000.0  Thousands
# 1          7.0             Marvel Studios    200.0     954.8   Millions
# 2          6.8             Marvel Studios    165.0     644.8   Millions
# 3          7.9             Marvel Studios    180.0     854.0   Millions
# 4          6.8             Marvel Studios    250.0     670.0   Millions
#
#   currency language  Age                                     Profit
# ...
